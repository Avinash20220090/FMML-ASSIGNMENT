# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinash20220090/FMML-ASSIGNMENT/blob/main/FMML_Module8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 17:47:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   209MB/s    in 0.3s
#
# 2023-05-27 17:47:06 (209 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2723   1708.08227v3  Generating molecules with desired chemical pro...  stat
# 28814  1707.08037v1  Automatic liver segmentation in 3D medical ima...    cs
# 11268  1506.07677v1  We take a new look at parameter estimation for...  stat
# 9338    1302.4245v3  Gaussian processes are rich distributions over...  stat
# 35623   1006.4474v1  We present the sTeX+ system, a user-driven adv...    cs
# ...             ...                                                ...   ...
# 401    1712.04248v2  Many machine learning algorithms are vulnerabl...  stat
# 6831   1706.05544v1  Rgtsvm provides a fast and flexible support ve...  stat
# 11567  1606.02702v1  In high dimensional settings, sparse structure...  stat
# 18722   1110.4719v1  This paper introduces the SEQ BIN meta-constra...    cs
# 27138  1702.05089v1  Text Proposals have emerged as a class-depende...    cs
#
#                                                    title  year  \
# 2723   ChemGAN challenge for drug discovery: can AI r...  2017
# 28814  Automatic Liver Segmentation Using an Adversar...  2017
# 11268  Manifold Optimization for Gaussian Mixture Models  2015
# 9338   Gaussian Process Kernels for Pattern Discovery...  2013
# 35623  sTeX+ - a System for Flexible Formalization of...  2010
# ...                                                  ...   ...
# 401    Decision-Based Adversarial Attacks: Reliable A...  2017
# 6831       Rgtsvm: Support Vector Machines on a GPU in R  2017
# 11567  Efficient Smoothed Concomitant Lasso Estimatio...  2016
# 18722  A Generalized Arc-Consistency Algorithm for a ...  2011
# 27138  Improving Text Proposals for Scene Images with...  2017
#
#                                                 keywords
# 2723   [generating, molecules, properties, important,...
# 28814  [automatic, segmentation, essential, applicati...
# 11268  [parameter, estimation, particular, emphrieman...
# 9338   [processes, distributions, functions, nonparam...
# 35623  [advancement, extension, producing, documents,...
# ...                                                  ...
# 401    [algorithms, vulnerable, imperceptible, pertur...
# 6831   [implementation, distinguishing, classificatio...
# 11567  [dimensional, structures, efficiency, computat...
# 18722  [introduces, constraint, algorithm, achieving,...
# 27138  [proposals, dependent, proposals, efficient, a...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2723     [generating, molecules, properties, important,...
# 28814    [automatic, segmentation, essential, applicati...
# 11268    [parameter, estimation, particular, emphrieman...
# 9338     [processes, distributions, functions, nonparam...
# 35623    [advancement, extension, producing, documents,...
#                                ...
# 17988    [compiling, preferences, semantics, preference...
# 13142    [widespread, sentiment, effectively, nesterovs...
# 22303    [classification, different, producing, differe...
# 37346    [indicator, definitions, calculate, comparison...
# 2906     [measuring, naturalness, important, realistic,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8875 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="75c02777-f8bc-43ce-9548-e2508d04e6a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75c02777-f8bc-43ce-9548-e2508d04e6a6")) {                    Plotly.newPlot(                        "75c02777-f8bc-43ce-9548-e2508d04e6a6",                        [{"x":["nontrivial","important","promising","generated","generative","generating","discovery","reproduce","stimulate","illustrate","following","properties","molecules","inspection","introduced","diversity","reinforcement","challenge","direction","automatic","segmentation","adversarial","discriminate","background","architecture","outperforms","performance","pathological","populations","employing","challenging","variations","resolution","assessment","applications","computing","solutions","postoperative","different","supervision","diagnosis","annotated","efficiency","algorithm","efficient","concatenation","essential","protocols","appearance","convolutional","practical","highlight","consideration","converges","encouraging","convexity","counterpart","programming","optimization","nonlinear","estimation","remarkable","expectation","displaying","particular","parameter","outperform","encourage","developing","strengths","variability","maximization","consequences","empirical","intuition","competitive","invocation","distributions","functions","framework","synthetic","covariances","passenger","introduce","smoothing","nonparametric","transform","extrapolation","discovering","atmospheric","stationary","inference","performing","reconstruct","modelling","processes","demonstrate","interpolation","formalization","authoring","engineering","processing","information","annotations","vocabularies","relations","originally","ultimately","documents","advancement","preserved","producing","structural","extension","retrieval","statistical","significantly","techniques","intrusion","scenarios","authentication","legitimate","adversary","generally","principled","classification","technique","detection","alternative","classical","benchmarks","conditions","successful","resulting","therefore","accurately","furthermore","prediction","predicting","evaluation","robustness","algorithms","performances","accounting","complexity","introduction","providing","competing","semidefinite","comparison","conditioned","relaxation","specified","simulations","approximate","parameters","numerical","including","universality","addressed","independent","similarities","biometric","experimental","regularization","synthesis","deficiencies","parametric","transformation","supervised","knowledge","extracted","discriminative","preferences","complexities","theoretical","additionally","simultaneously","dictionary","intrinsic","efficiently","accuracies","dramatically","estimated","assumption","potential","consistency","guarantees","sequential","lipschitz","sufficient","condition","formulate","strategies","realistic","additional","benchmark","questions","syntactically","semantics"],"y":[5,336,115,172,108,98,56,10,3,77,86,198,7,4,115,45,122,163,41,172,201,96,13,83,269,265,894,3,16,30,300,59,133,48,436,140,154,2,742,46,44,72,185,795,388,5,76,14,91,369,132,27,19,30,18,8,15,123,329,67,209,19,34,0,253,134,97,14,63,14,27,34,15,128,20,117,2,126,225,557,131,1,1,331,12,15,51,0,27,4,24,206,100,42,60,112,589,15,10,6,60,298,699,61,4,85,12,10,71,9,13,31,79,87,110,175,252,372,11,96,10,3,13,69,32,503,243,339,109,105,85,141,68,133,153,60,166,229,87,267,112,575,46,9,237,25,85,25,6,134,21,22,43,40,107,232,87,265,4,43,120,27,20,408,85,49,5,35,67,208,346,94,113,44,15,147,79,121,50,36,164,26,24,59,78,142,54,67,76,7,62,51,60,84,69,129,237,64,7,109],"type":"bar"},{"x":["nontrivial","important","promising","generated","generative","generating","discovery","reproduce","stimulate","ill ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Triplet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embedding</span> <span style=''>for</span> <span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.9523809523809524);'>Verification</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>Despite</span> <span style='background-color:rgba(0, 255, 0, 0.3238636363636363);'>significant</span> <span style=''>progress</span> <span style=''>made</span> <span style=''>over</span> <span style=''>the</span> <span style=''>past</span> <span style=''>twenty</span> <span style=''>five</span> <span style=''>years</span> <span style='background-color:rgba(0, 255, 0, 0.5135135135135135);'>unconstrained</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.9523809523809524);'>verification</span> <span style=''>remains</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.45985401459854014);'>challenging</span> <span style=''>problem</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>couples</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>CNN</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>with</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.36860670194003525);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.5066666666666666);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>learned</span> <span style=''>using</span> <span style=''>triplet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5135135135135135);'>unconstrained</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.9523809523809524);'>verification</span> <span style=''>problem</span> <span style=''>Aside</span> <span style=''>from</span> <span style=''>yielding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.41401273885350326);'>improvements</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>provides</span> <span style='background-color:rgba(0, 255, 0, 0.3238636363636363);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>memory</span> <span style=''>and</span> <span style=''>for</span> <span style=''>post</span> <span style='background-color:rgba(0, 255, 0, 0.44309927360774826);'>processing</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363636);'>operations</span> <span style=''>like</span> <span style=''>subject</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.45985401459854014);'>challenging</span> <span style=''>IJB</span> <span style=''>A</span> <span style=''>dataset</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>performs</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>comparably</span> <span style=''>or< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Curve</span> <span style=''>Learning</span> <span style=''>Coulomb</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Repulsion</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Electrostatic</span> <span style=''>Gaussian</span> <span style=''>Process</span> <br/><br/><span style=''>Learning</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>One</span> <span style=''>common</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>suppose</span> <span style=''>that</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>are</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>lower</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>smooth</span> <span style=''>manifold</span> <span style=''>There</span> <span style=''>are</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>which</span> <span style=''>allow</span> <span style=''>mapping</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>to</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>However</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>clear</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>allow</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>along</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>The</span> <span style=''>best</span> <span style=''>attempt</span> <span style=''>is</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style=''>(GP</span> <span style=''>LVM)</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiability</span> <span style=''>issues</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>poor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>We</span> <span style=''>solve</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposing</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>Coulomb</span> <span style=''>repulsive</span> <span style=''>process</span> <span style=''>(Corp)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>of</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.523076923076923);'>Regularized</span> <span style=''>Trees</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3004115226337449);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>many</span> <span style=''>tree</span> <span style=''>models</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3004115226337449);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>to</span> <span style=''>penalize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>new</span> <span style=''>feature</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>splitting</span> <span style=''>when</span> <span style=''>its</span> <span style=''>gain</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>gain)</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>features</span> <span style=''>used</span> <span style=''>in</span> <span style=''>previous</span> <span style=''>splits</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3004115226337449);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>on</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>and</span> <span style=''>boosted</span> <span style=''>trees</span> <span style=''>here</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>other</span> <span style=''>tree</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.41913043478260864);'>Experimental</span> <span style=''>studies</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.523076923076923);'>regularized</span> <span style=''>trees</span> <span style=''>can</span> <span style=''>select</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>feature</span> <span style=''>subsets</span> <span style=''>with</span> <span style=''>regard</span> <span style=''>to</span> <span style=''>both</span> <span style=''>strong</span> <span style=''>and</span> <span style=''>weak</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>Because</span> <span style=''>tree</span> <span style=''>models</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>deal</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categorical</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.4);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3316326530612245);'>variables</span> <span style=''>missing</span> <span style=''>values</span> <span style='background-color:rgba(0, 255, 0, 0.31560283687943264);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>Models</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <br/><br/><span style=''>Modern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>the</span> <span style=''>axiom</span> <span style=''>that</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>lie</span> <span style=''>near</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>revisits</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>and</span> <span style=''>puts</span> <span style=''>forth</span> <span style=''>two</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style=''>models</span> <span style=''>for</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describing</span> <span style=''>related</span> <span style=''>objectsphenomena</span> <span style=''>The</span> <span style=''>first</span> <span style=''>one</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>straddles</span> <span style=''>the</span> <span style=''>two</span> <span style=''>extremes</span> <span style=''>of</span> <span style=''>the</span> <span style=''>subspace</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style=''>union</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>model</span> <span style=''>and</span> <span style=''>is</span> <span style=''>termed</span> <span style=''>the</span> <span style=''>metric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>union</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>(MC</span> <span style=''>UoS)</span> <span style=''>model</span> <span style=''>The</span> <span style=''>second</span> <span style=''>one</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>suited</span> <span style=''>for</span> <span style=''>data</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>subspace</span> <span style=''>model</span> <span style=''>and</span> <span style=''>is</span> <span style=''>termed</span> <span style=''>the</span> <span style=''>metric</span> <span style='background-color:rgba(0, 255, 0,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.07147937411095306)
# 	challenging (0.10668563300142248)
# 	representation (0.13157894736842105)
# 	architecture (0.09566145092460882)
# 	information (0.24857752489331436)
# 	experimental (0.14509246088193456)
# 	detection (0.1205547652916074)
# 	different (0.26386913229018494)
# 	convolutional (0.13122332859174965)
# 	recognition (0.12304409672830725)
#
# Some Statistics words are:
# 	variables (0.1312877263581489)
# 	estimation (0.16549295774647887)
# 	statistical (0.153420523138833)
# 	stochastic (0.13732394366197184)
# 	theoretical (0.1488933601609658)
# 	algorithm (0.3908450704225352)
# 	distribution (0.1921529175050302)
# 	dimensional (0.19517102615694165)
# 	inference (0.2052313883299799)
# 	regression (0.18712273641851107)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="96240e5e-fed0-4595-8fff-825155329701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96240e5e-fed0-4595-8fff-825155329701")) {                    Plotly.newPlot(                        "96240e5e-fed0-4595-8fff-825155329701",                        [{"x":["nontrivial","important","promising","generated","generative","generating","discovery","reproduce","stimulate","illustrate","following","properties","molecules","inspection","introduced","diversity","reinforcement","challenge","direction","automatic","segmentation","adversarial","discriminate","background","architecture","outperforms","performance","pathological","populations","employing","challenging","variations","resolution","assessment","applications","computing","solutions","postoperative","different","supervision","diagnosis","annotated","efficiency","algorithm","efficient","concatenation","essential","protocols","appearance","convolutional","practical","highlight","consideration","converges","encouraging","convexity","counterpart","programming","optimization","nonlinear","estimation","remarkable","expectation","displaying","particular","parameter","outperform","encourage","developing","strengths","variability","maximization","consequences","empirical","intuition","competitive","invocation","distributions","functions","framework","synthetic","covariances","passenger","introduce","smoothing","nonparametric","transform","extrapolation","discovering","atmospheric","stationary","inference","performing","reconstruct","modelling","processes","demonstrate","interpolation","formalization","authoring","engineering","processing","information","annotations","vocabularies","relations","originally","ultimately","documents","advancement","preserved","producing","structural","extension","retrieval","statistical","significantly","techniques","intrusion","scenarios","authentication","legitimate","adversary","generally","principled","classification","technique","detection","alternative","classical","benchmarks","conditions","successful","resulting","therefore","accurately","furthermore","prediction","predicting","evaluation","robustness","algorithms","performances","accounting","complexity","introduction","providing","competing","semidefinite","comparison","conditioned","relaxation","specified","simulations","approximate","parameters","numerical","including","universality","addressed","independent","similarities","biometric","experimental","regularization","synthesis","deficiencies","parametric","transformation","supervised","knowledge","extracted","discriminative","preferences","complexities","theoretical","additionally","simultaneously","dictionary","intrinsic","efficiently","accuracies","dramatically","estimated","assumption","potential","consistency","guarantees","sequential","lipschitz","sufficient","condition","formulate","strategies","realistic","additional","benchmark","questions","syntactically","semantics","interrogation","syntactic","partitions","linguistic","separates","instances","approaches","equivalence","attractive","logically","computational","characterization","entailment","partition","leveraging","hierarchical","particularly","computationally","regularized","carefully","aggressive","selection","experiments","constructed","estimators","contribution","restricted","intensive","expensive","structured","alignment","considerably","convergent","conditional","literature","considers","mechanism","combining","participating","correlations","forecasting","combination","individual","improvement","developed","forecasts","relationships","parallelized","reparameterization","demonstrated","posterior","uncertainty","translates","parameterizations","investigate","proportionally","datapoints","pa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	displaying
# 	extrapolation
# 	proportionally
# 	nesterovs
# 	workhorse
# 	stochasticity
# 	penalizations
# 	assimilating
# 	candecompparafac
# 	multitype
# 	connectome
# 	jackknife
# 	majorizer
# 	normalised
# 	coarsening
# 	dermatological
# 	assortativity
# 	dendrogram
# 	ultrametric
# 	byproduct
# Some words which never appear in Statistics papers:
# 	postoperative
# 	concatenation
# 	authoring
# 	syntactically
# 	interrogation
# 	syntactic
# 	logically
# 	milliseconds
# 	homography
# 	conception
# 	operative
# 	approvals
# 	recruited
# 	messaging
# 	questionnaire
# 	discussions
# 	accessories
# 	sunglasses
# 	grayscale
# 	occlusions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0604437643458305e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
